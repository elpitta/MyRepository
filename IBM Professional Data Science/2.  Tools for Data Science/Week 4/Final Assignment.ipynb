# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Breno Bartholomeu Pitta__
# I am currently a student of science and technology / computer science at UFABC. I intend to specialize in data science, specifically in machine learning

# %% [markdown]
# ### My code below will perform a math operation

# %%
5**5
# Out:
# 3125

# %% [markdown]
# > Hello!!
# >
#  - THX
#  - WOW
#
# <hr>
#
# Thanks
